# %% [markdown]
# #z_score
# z=(x-mean)/sd

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
import scipy.stats as stats

# %%
data=[6,10,7,11,20,22,13,14,56,300]

# %%
stats.zscore(data)
# Out:
# array([-0.46501444, -0.41839645, -0.45335994, -0.40674195, -0.30185148,
#        -0.27854248, -0.38343296, -0.37177846,  0.11771042,  2.96140772])

# %%
df=pd.read_csv("cardio_vascular.csv")

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df1=df.copy()

# %%
df1.apply(stats.zscore)
# Out:
#            age       sex        cp  trestbps      chol       fbs   restecg  \
# 0    -0.268674  0.661504 -0.915755 -0.377636 -0.659332 -0.418878  0.891255
# 1    -0.158385  0.661504 -0.915755  0.479107 -0.833861  2.387330 -1.004049
# 2     1.716520  0.661504 -0.915755  0.764688 -1.396233 -0.418878  0.891255
# 3     0.723923  0.661504 -0.915755  0.936037 -0.833861 -0.418878  0.891255
# 4     0.834212 -1.511706 -0.915755  0.364875  0.930822  2.387330  0.891255
# ...        ...       ...       ...       ...       ...       ...       ...
# 1020  0.503346  0.661504  0.055931  0.479107 -0.484803 -0.418878  0.891255
# 1021  0.613635  0.661504 -0.915755 -0.377636  0.232705 -0.418878 -1.004049
# 1022 -0.820116  0.661504 -0.915755 -1.234378  0.562371 -0.418878 -1.004049
# 1023 -0.489251 -1.511706 -0.915755 -1.234378  0.155137 -0.418878 -1.004049
# 1024 -0.048097  0.661504 -0.915755 -0.663216 -1.124743 -0.418878  0.891255
#
# ...

# %%
# scalling or standarization data with zscore

# %%
# standarization or scalling with z approachb

# %%
# scaling approach with sklearn libraries

# %%
from sklearn.preprocessing import StandardScaler

# %%
df2=df.copy()

# %%
scale=StandardScaler()

# %%
df2_scaled=scale.fit_transform(df2)

# %%
df2_scaled
# Out:
# array([[-0.26867367,  0.66150409, -0.91575542, ...,  1.20922066,
#          1.08985168, -1.02669772],
#        [-0.15838512,  0.66150409, -0.91575542, ..., -0.73197147,
#          1.08985168, -1.02669772],
#        [ 1.71652022,  0.66150409, -0.91575542, ..., -0.73197147,
#          1.08985168, -1.02669772],
#        ...,
#        [-0.82011641,  0.66150409, -0.91575542, ...,  0.23862459,
#         -0.52212231, -1.02669772],
#        [-0.48925076, -1.51170646, -0.91575542, ..., -0.73197147,
#         -0.52212231,  0.97399651],
#        [-0.04809657,  0.66150409, -0.91575542, ...,  0.23862459,
#          1.08985168, -1.02669772]])

# %%
# pl. note:- when we import any function from sklearn it return arrays format

# %%
# how to convert array to dataframe

# %%
df2_new=pd.DataFrame(df2_scaled, columns=df2.columns)

# %%
df2_new.head()
# Out:
#         age       sex        cp  trestbps      chol       fbs   restecg  \
# 0 -0.268674  0.661504 -0.915755 -0.377636 -0.659332 -0.418878  0.891255
# 1 -0.158385  0.661504 -0.915755  0.479107 -0.833861  2.387330 -1.004049
# 2  1.716520  0.661504 -0.915755  0.764688 -1.396233 -0.418878  0.891255
# 3  0.723923  0.661504 -0.915755  0.936037 -0.833861 -0.418878  0.891255
# 4  0.834212 -1.511706 -0.915755  0.364875  0.930822  2.387330  0.891255
#
#     thalach     exang   oldpeak     slope        ca      thal    target
# 0  0.820689 -0.712287 -0.060888  0.995433  1.209221  1.089852 -1.026698
# 1  0.254953  1.403928  1.727137 -2.243675 -0.731971  1.089852 -1.026698
# 2 -1.050593  1.403928  1.301417 -2.243675 -0.731971  1.089852 -1.026698
# 3  0.516062 -0.712287 -0.912329  0.995433  0.238625  1.089852 -1.026698
# 4 -1.877438 -0.712287  0.705408 -0.624121  2.179817 -0.522122 -1.026698

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

# %%
scale=MinMaxScaler()# try at home this method

# %%
df3=df.copy()

# %%
df3_scaled=scale.fit_transform(df3)

# %%
df3_scaled
# Out:
# array([[0.47916667, 1.        , 0.        , ..., 0.5       , 1.        ,
#         0.        ],
#        [0.5       , 1.        , 0.        , ..., 0.        , 1.        ,
#         0.        ],
#        [0.85416667, 1.        , 0.        , ..., 0.        , 1.        ,
#         0.        ],
#        ...,
#        [0.375     , 1.        , 0.        , ..., 0.25      , 0.66666667,
#         0.        ],
#        [0.4375    , 0.        , 0.        , ..., 0.        , 0.66666667,
#         1.        ],
#        [0.52083333, 1.        , 0.        , ..., 0.25      , 1.        ,
#         0.        ]])

# %%
df3_new=pd.DataFrame(df3_scaled, columns=df3.columns)
df3_new
# Out:
#            age  sex        cp  trestbps      chol  fbs  restecg   thalach  \
# 0     0.479167  1.0  0.000000  0.292453  0.196347  0.0      0.5  0.740458
# 1     0.500000  1.0  0.000000  0.433962  0.175799  1.0      0.0  0.641221
# 2     0.854167  1.0  0.000000  0.481132  0.109589  0.0      0.5  0.412214
# 3     0.666667  1.0  0.000000  0.509434  0.175799  0.0      0.5  0.687023
# 4     0.687500  0.0  0.000000  0.415094  0.383562  1.0      0.5  0.267176
# ...        ...  ...       ...       ...       ...  ...      ...       ...
# 1020  0.625000  1.0  0.333333  0.433962  0.216895  0.0      0.5  0.709924
# 1021  0.645833  1.0  0.000000  0.292453  0.301370  0.0      0.0  0.534351
# 1022  0.375000  1.0  0.000000  0.150943  0.340183  0.0      0.0  0.358779
# 1023  0.437500  0.0  0.000000  0.150943  0.292237  0.0      0.0  0.671756
# 1024  0.520833  1.0  0.000000  0.245283  0.141553  0.0      0.5  0.320611
#
#       exang   oldpeak  slope    ca      thal  target
# ...

# %%
scale=RobustScaler()

# %%
df4=df.copy()

# %%
df4_scaled=scale.fit_transform(df4)

# %%
df4_scaled
# Out:
# array([[-0.30769231,  0.        , -0.5       , ...,  2.        ,
#          1.        , -1.        ],
#        [-0.23076923,  0.        , -0.5       , ...,  0.        ,
#          1.        , -1.        ],
#        [ 1.07692308,  0.        , -0.5       , ...,  0.        ,
#          1.        , -1.        ],
#        ...,
#        [-0.69230769,  0.        , -0.5       , ...,  1.        ,
#          0.        , -1.        ],
#        [-0.46153846, -1.        , -0.5       , ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.15384615,  0.        , -0.5       , ...,  1.        ,
#          1.        , -1.        ]])

# %%
df4_new=pd.DataFrame(df4_scaled, columns=df4.columns)

# %%
df4_new
# Out:
#            age  sex   cp  trestbps      chol  fbs  restecg   thalach  exang  \
# 0    -0.307692  0.0 -0.5     -0.25 -0.437500  0.0      0.0  0.470588    0.0
# 1    -0.230769  0.0 -0.5      0.50 -0.578125  1.0     -1.0  0.088235    1.0
# 2     1.076923  0.0 -0.5      0.75 -1.031250  0.0      0.0 -0.794118    1.0
# 3     0.384615  0.0 -0.5      0.90 -0.578125  0.0      0.0  0.264706    0.0
# 4     0.461538 -1.0 -0.5      0.40  0.843750  1.0      0.0 -1.352941    0.0
# ...        ...  ...  ...       ...       ...  ...      ...       ...    ...
# 1020  0.230769  0.0  0.0      0.50 -0.296875  0.0      0.0  0.352941    1.0
# 1021  0.307692  0.0 -0.5     -0.25  0.281250  0.0     -1.0 -0.323529    1.0
# 1022 -0.692308  0.0 -0.5     -1.00  0.546875  0.0     -1.0 -1.000000    1.0
# 1023 -0.461538 -1.0 -0.5     -1.00  0.218750  0.0     -1.0  0.205882    0.0
# 1024 -0.153846  0.0 -0.5     -0.50 -0.812500  0.0      0.0 -1.147059    0.0
#
#        oldpeak  slope   ca  thal  target
# ...

# %%
#degree of skewness and kurtosis

# %%
df2.skew()
# Out:
# age        -0.249478
# sex        -0.851449
# cp          0.529455
# trestbps    0.739768
# chol        1.074073
# fbs         1.971339
# restecg     0.180440
# thalach    -0.516791
# exang       0.692655
# oldpeak     1.210899
# slope      -0.479134
# ca          1.261189
# thal       -0.524390
# target     -0.052778
# dtype: float64

# %%
df2.kurt()# you can keep +-5 normaly data distributed
# Out:
# age        -0.524644
# sex        -1.277531
# cp         -1.149500
# trestbps    0.991221
# chol        3.996803
# fbs         1.889859
# restecg    -1.309614
# thalach    -0.080328
# exang      -1.523205
# oldpeak     1.314471
# slope      -0.647129
# ca          0.701123
# thal        0.250827
# target     -2.001123
# dtype: float64

# %%
# sampling

# %%
df2.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df2.shape
# Out:
# (1025, 14)

# %%
sample1=df2.sample()
sample1
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 917   47    1   2       130   253    0        1      179      0      0.0
#
#      slope  ca  thal  target
# 917      2   0     2       1

# %%
sample2=df2.sample(n=4)
sample2
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 237   57    1   1       124   261    0        1      141      0      0.3
# 438   47    1   2       130   253    0        1      179      0      0.0
# 398   66    1   0       160   228    0        0      138      0      2.3
# 753   65    1   0       120   177    0        1      140      0      0.4
#
#      slope  ca  thal  target
# 237      2   0     3       0
# 438      2   0     2       1
# 398      2   0     1       1
# 753      2   0     3       1

# %%
sample3=df2.sample(frac=0.01)
sample3
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 554   58    1   0       100   234    0        1      156      0      0.1
# 974   43    1   0       110   211    0        1      161      0      0.0
# 50    58    0   3       150   283    1        0      162      0      1.0
# 414   59    1   3       170   288    0        0      159      0      0.2
# 112   48    1   0       130   256    1        0      150      1      0.0
# 640   46    0   0       138   243    0        0      152      1      0.0
# 213   43    1   2       130   315    0        1      162      0      1.9
# 46    41    1   1       135   203    0        1      132      0      0.0
# 300   46    0   1       105   204    0        1      172      0      0.0
# 257   64    0   0       180   325    0        1      154      1      0.0
#
#      slope  ca  thal  target
# 554      2   1     3       0
# 974      2   0     3       1
# 50       2   0     2       1
# 414      1   0     3       0
# ...

# %%
# this all above simple random approach

# %%
# reproduce the random selected data use(random_state)this wil fix the same sample

# %%
sample4=df2.sample(n=5, random_state=30)
sample4
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 288   58    0   2       120   340    0        1      172      0      0.0
# 132   41    1   1       135   203    0        1      132      0      0.0
# 127   53    1   2       130   197    1        0      152      0      1.2
# 485   62    1   1       120   281    0        0      103      0      1.4
# 834   42    1   0       136   315    0        1      125      1      1.8
#
#      slope  ca  thal  target
# 288      2   0     2       1
# 132      1   0     1       1
# 127      0   0     2       1
# 485      1   1     3       0
# 834      1   0     1       0

# %%
# train test split approach

# %%
# split the dependent and independent variable

# %%
X=df2.drop(['target'], axis=1)
Y=df2["target"]

# %%
X.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal
# 0   2     3
# 1   0     3
# 2   0     3
# 3   1     3
# 4   3     2

# %%
# splitting into training and testing data

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,train_size=0.80,random_state=10)

# %%
print(X_train.shape)
# Out:
# (820, 13)

# %%
X_test.shape
# Out:
# (205, 13)

# %%
Y_train.shape
# Out:
# (820,)

# %%
X_train.head()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 483   35    1   1       122   192    0        1      174      0      0.0
# 751   65    0   2       160   360    0        0      151      0      0.8
# 752   48    1   1       130   245    0        0      180      0      0.2
# 305   62    1   0       120   267    0        1       99      1      1.8
# 253   57    1   0       165   289    1        0      124      0      1.0
#
#      slope  ca  thal
# 483      2   0     2
# 751      2   0     2
# 752      1   0     2
# 305      1   2     3
# 253      1   3     3

# %%
Y.value_counts()
# Out:
# 1    526
# 0    499
# Name: target, dtype: int64

# %%
X_train1,X_test1,Y_train1,Y_test1=train_test_split(X,Y,train_size=0.80,random_state=100, stratify=Y)

# %%
# stratify we apply for imbalanced data Above

# %%
## lets build model and check the accuracy--just for learning of train test

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %% [raw]
# lr.fit(X_train,Y_train)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
y_predict=lr.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# /var/folders/n4/yztfqdn9297_v1sc0g059n5w0000gn/T/ipykernel_1259/1914568533.py in <module>
# ----> 1 y_predict=lr.predict(X_test)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     423             Vector containing the class labels for each sample.
#     424         """
# --> 425         scores = self.decision_function(X)
#     426         if len(scores.shape) == 1:
#     427             indices = (scores > 0).astype(int)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py in decision_function(self, X)
#     403             this class would be predicted.
#     404         """
# --> 405         check_is_fitted(self)
#     406
#     407         X = self._validate_data(X, accept_sparse="csr", reset=False)
#
# ...

# %%
accuracy_score(Y_test,y_predict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/n4/yztfqdn9297_v1sc0g059n5w0000gn/T/ipykernel_1259/431433752.py in <module>
# ----> 1 accuracy_score(Y_test,y_predict)
#
# NameError: name 'y_predict' is not defined

# %%
confusion_matrix(Y_test, y_predict)

# %%
# cross validation approach--training testing

# %%
from sklearn.model_selection import cross_val_score

# %%
log=LogisticRegression()

# %%
accuracy=cross_val_score(log,X,Y,cv=20)

# %%
accuracy
# Out:
# array([0.86538462, 0.88461538, 0.86538462, 0.94230769, 0.84615385,
#        0.8627451 , 0.88235294, 0.78431373, 0.84313725, 0.8627451 ,
#        0.8627451 , 0.94117647, 0.74509804, 0.8627451 , 0.78431373,
#        0.8627451 , 0.78431373, 0.76470588, 0.78431373, 0.82352941])

# %%
mean_accuracy=accuracy.mean()
mean_accuracy
# Out:
# 0.8427413273001509

# %%
df2.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
chol=df2['chol']

# %%
import seaborn as sns
sns.histplot(data=chol,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='chol', ylabel='Count'>

# %%
chol.shape
# Out:
# (1025,)

# %%
chol.mean()
# Out:
# 246.0

# %%
chol.std()
# Out:
# 51.59251020618206

# %%
sample1=chol.sample(n=50)

# %%
print(sample1.mean())
print(sample1.std())
# Out:
# 240.72
# 37.91937741674392

# %%
sample1=chol.sample(n=100)
print(sample1.mean())
print(sample1.std())
# Out:
# 241.83
# 47.78572860787894

# %%
# above processs is the law of large number-- larger the number size..sample parameters closer to the population parameters

# %%
# central limit theorem
# create many no. of equal size(no. of member in. sample >=30)

# %%
sample_mean50=[]
for i in range(len(chol)):
    sample_mean50.append(chol.sample(50).mean())
sns.histplot(sample_mean50,kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>
